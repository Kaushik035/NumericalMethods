# %%
import numpy as np
import math

# %%
# Define the function and its derivative
def f(x):

    return x**3 -2*(x**2) + 4
# math.exp(-x) - x
# x**3 - x - 2
# math.cos(x) - x
# x**3 -2*(x**2) + 4

def f_prime(x):

    return 3*(x**2) - 4*x

# -math.exp(-x) - 1
# 3*x**2 - 1
# -math.sin(x) - 1
# 3*(x**2) - 4*x

# Define g(x) for the rearranged equation x = g(x)

def g(x):

    return -np.sqrt((x**3 + 4) / 2)

# math.exp(-x)
#  (x + 2) ** (1/3)
# math.cos(x)
# -np.sqrt((x**3 + 4) / 2)

# %% [markdown]
# * Bisection method

# %%
def bisection(func, a, b, tol=1e-6, max_iter=100):
    """
    Bisection method to find root of a function within interval [a, b].

    Parameters:
        func     : Function to evaluate
        a, b     : Interval where the function changes sign
        tol      : Tolerance for stopping criterion
        max_iter : Maximum number of iterations

    Returns:
        root, iterations
    """
    if func(a) * func(b) >= 0:
        print(func(a), func(b))
        raise ValueError("f(a) and f(b) must have opposite signs.")

    iteration_data = []

    for i in range(max_iter):
        mid = (a + b) / 2
        f_mid = func(mid)
        
        # Store iteration data
        iteration_data.append((i+1, a, b, mid, f_mid))

        if abs(f_mid) < tol or (b - a) / 2 < tol:
            return mid, iteration_data

        if func(a) * f_mid < 0:
            b = mid
        else:
            a = mid

    raise ValueError("Max iterations reached without convergence.")

# %% [markdown]
# * fixed point iteration

# %%
# Cell 3: Convergence check function
def check_convergence(g_func, x0):
    """
    Checks if |g'(x)| < 1 at x0.
    Uses numerical differentiation.
    """
    h = 1e-6
    g_prime = (g_func(x0 + h) - g_func(x0 - h)) / (2*h)  # central difference
    print(f"g'(x0) ≈ {g_prime:.6f}")
    if abs(g_prime) >= 1:
        print("Warning: |g'(x0)| >= 1 → May not converge.")
    else:
        print(" Convergence condition likely satisfied.")

# %%
# Cell 4: Implement Fixed Point Iteration
def fixed_point_iteration(g_func, x0, tol=1e-6, max_iter=100):
    """
    Fixed Point Iteration method to find the root using x = g(x).

    Parameters:
        g_func   : Function g(x) after rearranging f(x) = 0
        x0       : Initial guess
        tol      : Tolerance for stopping criterion
        max_iter : Maximum number of iterations

    Returns:
        root, iterations
    """
    # Check convergence condition first
    check_convergence(g_func, x0)

    iteration_data = []
    x_current = x0

    for i in range(max_iter):
        x_next = g_func(x_current)
        error = abs((x_next - x_current) / x_current) if x_current != 0 else abs(x_next - x_current)

        iteration_data.append((i+1, x_current, x_next, error))

        if error < tol:
            return x_next, iteration_data

        x_current = x_next

    raise ValueError("Max iterations reached without convergence.")

# %% [markdown]
# * Newton Rapson

# %%
# Cell 3: Implement the Newton–Raphson method
def newton_raphson(f_func, f_prime_func, x0, tol=1e-6, max_iter=100):
    """
    Newton–Raphson method to find root of f(x) = 0.

    Parameters:
        f_func       : Function f(x)
        f_prime_func : Derivative f'(x)
        x0           : Initial guess
        tol          : Tolerance for stopping criterion
        max_iter     : Maximum number of iterations

    Returns:
        root, iterations
    """
    iteration_data = []
    x_current = x0

    for i in range(max_iter):
        f_val = f_func(x_current)
        f_prime_val = f_prime_func(x_current)

        if f_prime_val == 0:
            raise ZeroDivisionError(f"Derivative zero at iteration {i+1}, x = {x_current}")

        x_next = x_current - f_val / f_prime_val
        error = abs(x_next - x_current)

        iteration_data.append((i+1, x_current, f_val, f_prime_val, x_next, error))

        if error < tol:
            return x_next, iteration_data

        x_current = x_next

    raise ValueError("Max iterations reached without convergence.")

# %% [markdown]
# * Secant Method

# %%
def secant_method(f, x0, x1, tol=1e-6, max_iter=100):
    """
    Secant Method for root finding.

    Parameters:
        f        : function
        x0, x1   : initial guesses (should be close to the root)
        tol      : tolerance for stopping
        max_iter : maximum number of iterations

    Returns:
        root, iteration_data
    """
    iteration_data = []

    for i in range(max_iter):
        f_x0 = f(x0)
        f_x1 = f(x1)

        # Avoid division by zero
        if f_x1 == f_x0:
            raise ZeroDivisionError("f(x1) and f(x0) became equal — division by zero in Secant formula.")

        # Secant update formula
        x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)

        # Store iteration data
        iteration_data.append((i+1, x0, x1, x2, f_x0, f_x1, abs(x2 - x1)))

        # Check convergence
        if abs(x2 - x1) < tol or abs(f(x2)) < tol:
            return x2, iteration_data

        # Update for next iteration
        x0, x1 = x1, x2

    # If max iterations reached
    raise ValueError("Maximum iterations reached without convergence.")

# %%
print("\n Bisection Method")
root_bis, iter_bis = bisection(f, a=-2, b=-1, tol=1e-6)
print(f"Estimated root: {root_bis:.6f} (Iterations: {len(iter_bis)})")
for it in iter_bis:
    print(f"Iter {it[0]}: a={it[1]:.6f}, b={it[2]:.6f}, mid={it[3]:.6f}, f(mid)={it[4]:.6e}")

print("\nNewton–Raphson Method")
root_nr, iter_nr = newton_raphson(f, f_prime, x0=-0.5, tol=1e-6)
print(f"Estimated root: {root_nr:.6f} (Iterations: {len(iter_nr)})")
for it in iter_nr:
    print(f"Iter {it[0]}: x={it[1]:.6f}, f(x)={it[2]:.6e}, f'(x)={it[3]:.6e}, x_next={it[4]:.6f}, error={it[5]:.6e}")

print("\n Fixed-Point Iteration ")
root_fp, iter_fp = fixed_point_iteration(g, x0=-0.5, tol=1e-6)
print(f"Estimated root: {root_fp:.6f} (Iterations: {len(iter_fp)})")
for it in iter_fp:
    print(f"Iter {it[0]}: x_current={it[1]:.6f}, x_next={it[2]:.6f}, error={it[3]:.6e}")

print("\n Secant Method ")
root_sec, iter_sec = secant_method(f, x0=-2, x1=-1, tol=1e-6, max_iter=100)
print(f"Estimated root: {root_sec:.6f} (Iterations: {len(iter_sec)})")
print("Iter |    x0       |    x1       |    x2       |   f(x0)      |   f(x1)      |   Error")
print("-"*80)
for it in iter_sec:
    print(f"{it[0]:>4} | {it[1]:>10.6f} | {it[2]:>10.6f} | {it[3]:>10.6f} | {it[4]:>10.6f} | {it[5]:>10.6f} | {it[6]:>10.6e}")
# Out:
#  Bisection Method
# Estimated root: -1.130395 (Iterations: 20)
# Iter 1: a=-2.000000, b=-1.000000, mid=-1.500000, f(mid)=-3.875000e+00
# Iter 2: a=-1.500000, b=-1.000000, mid=-1.250000, f(mid)=-1.078125e+00
# Iter 3: a=-1.250000, b=-1.000000, mid=-1.125000, f(mid)=4.492188e-02
# Iter 4: a=-1.250000, b=-1.125000, mid=-1.187500, f(mid)=-4.948730e-01
# Iter 5: a=-1.187500, b=-1.125000, mid=-1.156250, f(mid)=-2.196350e-01
# Iter 6: a=-1.156250, b=-1.125000, mid=-1.140625, f(mid)=-8.603287e-02
# Iter 7: a=-1.140625, b=-1.125000, mid=-1.132812, f(mid)=-2.022600e-02
# Iter 8: a=-1.132812, b=-1.125000, mid=-1.128906, f(mid)=1.243013e-02
# Iter 9: a=-1.132812, b=-1.128906, mid=-1.130859, f(mid)=-3.877364e-03
# Iter 10: a=-1.130859, b=-1.128906, mid=-1.129883, f(mid)=4.281524e-03
# Iter 11: a=-1.130859, b=-1.129883, mid=-1.130371, f(mid)=2.033651e-04
# Iter 12: a=-1.130859, b=-1.130371, mid=-1.130615, f(mid)=-1.836678e-03
# Iter 13: a=-1.130615, b=-1.130371, mid=-1.130493, f(mid)=-8.165762e-04
# Iter 14: a=-1.130493, b=-1.130371, mid=-1.130432, f(mid)=-3.065854e-04
# Iter 15: a=-1.130432, b=-1.130371, mid=-1.130402, f(mid)=-5.160514e-05
# Iter 16: a=-1.130402, b=-1.130371, mid=-1.130386, f(mid)=7.588124e-05
# Iter 17: a=-1.130402, b=-1.130386, mid=-1.130394, f(mid)=1.213836e-05
# Iter 18: a=-1.130402, b=-1.130394, mid=-1.130398, f(mid)=-1.973331e-05
# Iter 19: a=-1.130398, b=-1.130394, mid=-1.130396, f(mid)=-3.797457e-06
# Iter 20: a=-1.130396, b=-1.130394, mid=-1.130395, f(mid)=4.170457e-06
#
# Newton–Raphson Method
# Estimated root: -1.130395 (Iterations: 6)
# Iter 1: x=-0.500000, f(x)=3.375000e+00, f'(x)=2.750000e+00, x_next=-1.727273, error=1.227273e+00
# Iter 2: x=-1.727273, f(x)=-7.120210e+00, f'(x)=1.585950e+01, x_next=-1.278317, error=4.489554e-01
# Iter 3: x=-1.278317, f(x)=-1.357082e+00, f'(x)=1.001555e+01, x_next=-1.142820, error=1.354975e-01
# Iter 4: x=-1.142820, f(x)=-1.046395e-01, f'(x)=8.489391e+00, x_next=-1.130494, error=1.232591e-02
# Iter 5: x=-1.130494, f(x)=-8.228633e-04, f'(x)=8.356025e+00, x_next=-1.130395, error=9.847544e-05
# Iter 6: x=-1.130395, f(x)=-5.228247e-08, f'(x)=8.354963e+00, x_next=-1.130395, error=6.257654e-09
#
#  Fixed-Point Iteration
# g'(x0) ≈ -0.134704
# ✅ Convergence condition likely satisfied.
# Estimated root: -1.130396 (Iterations: 81)
# Iter 1: x_current=-0.500000, x_next=-1.391941, error=1.783882e+00
# Iter 2: x_current=-1.391941, x_next=-0.807191, error=4.200970e-01
# Iter 3: x_current=-0.807191, x_next=-1.317966, error=6.327812e-01
# Iter 4: x_current=-1.317966, x_next=-0.924837, error=2.982846e-01
# Iter 5: x_current=-0.924837, x_next=-1.266682, error=3.696268e-01
# Iter 6: x_current=-1.266682, x_next=-0.991875, error=2.169502e-01
# Iter 7: x_current=-0.991875, x_next=-1.229670, error=2.397433e-01
# Iter 8: x_current=-1.229670, x_next=-1.034560, error=1.586687e-01
# Iter 9: x_current=-1.034560, x_next=-1.202642, error=1.624670e-01
# Iter 10: x_current=-1.202642, x_next=-1.063147, error=1.159907e-01
# Iter 11: x_current=-1.063147, x_next=-1.182866, error=1.126088e-01
# Iter 12: x_current=-1.182866, x_next=-1.082812, error=8.458599e-02
# Iter 13: x_current=-1.082812, x_next=-1.168422, error=7.906246e-02
# Iter 14: x_current=-1.168422, x_next=-1.096553, error=6.150952e-02
# Iter 15: x_current=-1.096553, x_next=-1.157902, error=5.594675e-02
# Iter 16: x_current=-1.157902, x_next=-1.106246, error=4.461180e-02
# Iter 17: x_current=-1.106246, x_next=-1.150261, error=3.978774e-02
# Iter 18: x_current=-1.150261, x_next=-1.113124, error=3.228536e-02
# Iter 19: x_current=-1.113124, x_next=-1.144725, error=2.838903e-02
# Iter 20: x_current=-1.144725, x_next=-1.118025, error=2.332416e-02
# Iter 21: x_current=-1.118025, x_next=-1.140722, error=2.030076e-02
# Iter 22: x_current=-1.140722, x_next=-1.121526, error=1.682771e-02
# Iter 23: x_current=-1.121526, x_next=-1.137832, error=1.453892e-02
# Iter 24: x_current=-1.137832, x_next=-1.124032, error=1.212847e-02
# Iter 25: x_current=-1.124032, x_next=-1.135748, error=1.042339e-02
# Iter 26: x_current=-1.135748, x_next=-1.125827, error=8.734975e-03
# Iter 27: x_current=-1.125827, x_next=-1.134246, error=7.478341e-03
# Iter 28: x_current=-1.134246, x_next=-1.127115, error=6.287500e-03
# Iter 29: x_current=-1.127115, x_next=-1.133165, error=5.368186e-03
# Iter 30: x_current=-1.133165, x_next=-1.128039, error=4.523967e-03
# Iter 31: x_current=-1.128039, x_next=-1.132387, error=3.854871e-03
# Iter 32: x_current=-1.132387, x_next=-1.128702, error=3.254120e-03
# Iter 33: x_current=-1.128702, x_next=-1.131828, error=2.768893e-03
# Iter 34: x_current=-1.131828, x_next=-1.129179, error=2.340214e-03
# Iter 35: x_current=-1.129179, x_next=-1.131425, error=1.989224e-03
# Iter 36: x_current=-1.131425, x_next=-1.129521, error=1.682716e-03
# Iter 37: x_current=-1.129521, x_next=-1.131136, error=1.429287e-03
# Iter 38: x_current=-1.131136, x_next=-1.129767, error=1.209812e-03
# Iter 39: x_current=-1.129767, x_next=-1.130928, error=1.027063e-03
# Iter 40: x_current=-1.130928, x_next=-1.129944, error=8.697420e-04
# Iter 41: x_current=-1.129944, x_next=-1.130778, error=7.380814e-04
# Iter 42: x_current=-1.130778, x_next=-1.130071, error=6.252272e-04
# Iter 43: x_current=-1.130071, x_next=-1.130670, error=5.304360e-04
# Iter 44: x_current=-1.130670, x_next=-1.130162, error=4.494354e-04
# Iter 45: x_current=-1.130162, x_next=-1.130593, error=3.812212e-04
# Iter 46: x_current=-1.130593, x_next=-1.130228, error=3.230605e-04
# Iter 47: x_current=-1.130228, x_next=-1.130537, error=2.739884e-04
# Iter 48: x_current=-1.130537, x_next=-1.130275, error=2.322154e-04
# Iter 49: x_current=-1.130275, x_next=-1.130498, error=1.969225e-04
# Iter 50: x_current=-1.130498, x_next=-1.130309, error=1.669135e-04
# Iter 51: x_current=-1.130309, x_next=-1.130469, error=1.415351e-04
# Iter 52: x_current=-1.130469, x_next=-1.130333, error=1.199740e-04
# Iter 53: x_current=-1.130333, x_next=-1.130448, error=1.017272e-04
# Iter 54: x_current=-1.130448, x_next=-1.130351, error=8.623414e-05
# Iter 55: x_current=-1.130351, x_next=-1.130433, error=7.311605e-05
# Iter 56: x_current=-1.130433, x_next=-1.130363, error=6.198247e-05
# Iter 57: x_current=-1.130363, x_next=-1.130423, error=5.255217e-05
# Iter 58: x_current=-1.130423, x_next=-1.130372, error=4.455093e-05
# Iter 59: x_current=-1.130372, x_next=-1.130415, error=3.777201e-05
# Iter 60: x_current=-1.130415, x_next=-1.130379, error=3.202163e-05
# Iter 61: x_current=-1.130379, x_next=-1.130410, error=2.714880e-05
# Iter 62: x_current=-1.130410, x_next=-1.130383, error=2.301596e-05
# Iter 63: x_current=-1.130383, x_next=-1.130406, error=1.951335e-05
# Iter 64: x_current=-1.130406, x_next=-1.130387, error=1.654299e-05
# Iter 65: x_current=-1.130387, x_next=-1.130403, error=1.402535e-05
# Iter 66: x_current=-1.130403, x_next=-1.130389, error=1.189046e-05
# Iter 67: x_current=-1.130389, x_next=-1.130401, error=1.008083e-05
# Iter 68: x_current=-1.130401, x_next=-1.130391, error=8.546393e-06
# Iter 69: x_current=-1.130391, x_next=-1.130399, error=7.245672e-06
# Iter 70: x_current=-1.130399, x_next=-1.130392, error=6.142806e-06
# Iter 71: x_current=-1.130392, x_next=-1.130398, error=5.207886e-06
# Iter 72: x_current=-1.130398, x_next=-1.130393, error=4.415202e-06
# Iter 73: x_current=-1.130393, x_next=-1.130397, error=3.743211e-06
# Iter 74: x_current=-1.130397, x_next=-1.130394, error=3.173469e-06
# Iter 75: x_current=-1.130394, x_next=-1.130397, error=2.690465e-06
# Iter 76: x_current=-1.130397, x_next=-1.130394, error=2.280960e-06
# Iter 77: x_current=-1.130394, x_next=-1.130396, error=1.933795e-06
# Iter 78: x_current=-1.130396, x_next=-1.130395, error=1.639462e-06
# Iter 79: x_current=-1.130395, x_next=-1.130396, error=1.389932e-06
# Iter 80: x_current=-1.130396, x_next=-1.130395, error=1.178378e-06
# Iter 81: x_current=-1.130395, x_next=-1.130396, error=9.990263e-07
#
#  Secant Method
# Estimated root: -1.130395 (Iterations: 5)
# Iter |    x0       |    x1       |    x2       |   f(x0)      |   f(x1)      |   Error
# --------------------------------------------------------------------------------
#    1 |  -2.000000 |  -1.000000 |  -1.076923 | -12.000000 |   1.000000 | 7.692308e-02
#    2 |  -1.000000 |  -1.076923 |  -1.135308 |   1.000000 |   0.431497 | 5.838517e-02
#    3 |  -1.076923 |  -1.135308 |  -1.130222 |   0.431497 |  -0.041177 | 5.086174e-03
#    4 |  -1.135308 |  -1.130222 |  -1.130395 |  -0.041177 |   0.001448 | 1.728141e-04
#    5 |  -1.130222 |  -1.130395 |  -1.130395 |   0.001448 |   0.000005 | 5.484384e-07
